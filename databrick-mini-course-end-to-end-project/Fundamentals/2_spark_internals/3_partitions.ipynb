# %% [markdown]
# ### Partition Tutorial

# %%
df = spark.table("workspace.default.movies")
display(df.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>title</th><th>industry</th><th>release_year</th><th>imdb_rating</th><th>studio</th><th>budget</th><th>revenue</th><th>unit</th><th>currency</th><th>language</th></tr></thead><tbody><tr><td>Pather Panchali</td><td>Bollywood</td><td>1955</td><td>8.3</td><td>Government of West Bengal</td><td>70000.0</td><td>100000.0</td><td>Thousands</td><td>INR</td><td>Bengali</td></tr><tr><td>Doctor Strange in the Multiverse of Madness</td><td>Hollywood</td><td>2022</td><td>7</td><td>Marvel Studios</td><td>200.0</td><td>954.8</td><td>Millions</td><td>USD</td><td>English</td></tr><tr><td>Thor: The Dark World </td><td>Hollywood</td><td>2013</td><td>6.8</td><td>Marvel Studios</td><td>165.0</td><td>644.8</td><td>Millions</td><td>USD</td><td>English</td></tr><tr><td>Thor: Ragnarok </td><td>Hollywood</td><td>2017</td><td>7.9</td><td>Marvel Studios</td><td>180.0</td><td>854.0</td><td>Millions</td><td>USD</td><td>English</td></tr><tr><td>Thor: Love and Thunder </td><td>Hollywood</td><td>2022</td><td>6.8</td><td>Marvel Studios</td><td>250.0</td><td>670.0</td><td>Millions</td><td>USD</td><td>English</td></tr></tbody></table></div>

# %%
# %sql
select distinct studio from workspace.default.movies
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>studio</th></tr></thead><tbody><tr><td>Government of West Bengal</td></tr><tr><td>Marvel Studios</td></tr><tr><td>Castle Rock Entertainment</td></tr><tr><td>Warner Bros. Pictures</td></tr><tr><td>Columbia Pictures</td></tr><tr><td>Universal Pictures  </td></tr><tr><td>Paramount Pictures</td></tr><tr><td>Liberty Films</td></tr><tr><td>20th Century Fox</td></tr><tr><td>Syncopy</td></tr><tr><td>Universal Pictures</td></tr><tr><td>Yash Raj Films</td></tr><tr><td>Vinod Chopra Films</td></tr><tr><td>Dharma Productions</td></tr><tr><td>Vinod Chopra Productions</td></tr><tr><td>Zee Studios</td></tr><tr><td>Salman Khan Films</td></tr><tr><td>Hombale Films</td></tr><tr><td>Mythri Movie Makers</td></tr><tr><td>DVV Entertainment</td></tr><tr><td>Arka Media Works</td></tr><tr><td>null</td></tr></tbody></table></div>

# %% [markdown]
# ### Partition by Key

# %%
# Partition by a key (better data grouping for future groupBy/join on that key)
rep_by_key = df.repartition(6, "studio")  # Exchange hashpartitioning(studio, 6)
rep_by_key.explain("formatted")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (7)
# +- == Initial Plan ==
#    ColumnarToRow (6)
#    +- PhotonResultStage (5)
#       +- PhotonShuffleExchangeSource (4)
#          +- PhotonShuffleMapStage (3)
#             +- PhotonShuffleExchangeSink (2)
#                +- PhotonScan parquet workspace.default.movies (1)
#
#
# (1) PhotonScan parquet workspace.default.movies
# Output [10]: [title#11597, industry#11598, release_year#11599L, imdb_rating#11600, studio#11601, budget#11602, revenue#11603, unit#11604, currency#11605, language#11606]
# Location: PreparedDeltaFileIndex [s3://dbstorage-prod-ftgok/uc/79a99d11-bc4e-43f0-a401-b12e20be6025/fba37f23-14f9-4927-9ade-961e9f768757/__unitystorage/catalogs/175a67df-9974-43f3-a33a-f690ccef30f2/tables/bd69b1e4-307f-4ceb-8369-e74cf80f21d7]
# ReadSchema: struct<title:string,industry:string,release_year:bigint,imdb_rating:string,studio:string,budget:double,revenue:double,unit:string,currency:string,language:string>
#
# (2) PhotonShuffleExchangeSink
# Input [10]: [title#11597, industry#11598, release_year#11599L, imdb_rating#11600, studio#11601, budget#11602, revenue#11603, unit#11604, currency#11605, language#11606]
# Arguments: hashpartitioning(studio#11601, 6)
#
# (3) PhotonShuffleMapStage
# Input [10]: [title#11597, industry#11598, release_year#11599L, imdb_rating#11600, studio#11601, budget#11602, revenue#11603, unit#11604, currency#11605, language#11606]
# Arguments: REPARTITION_BY_NUM, [id=#7722]
#
# (4) PhotonShuffleExchangeSource
# Input [10]: [title#11597, industry#11598, release_year#11599L, imdb_rating#11600, studio#11601, budget#11602, revenue#11603, unit#11604, currency#11605, language#11606]
#
# (5) PhotonResultStage
# Input [10]: [title#11597, industry#11598, release_year#11599L, imdb_rating#11600, studio#11601, budget#11602, revenue#11603, unit#11604, currency#11605, language#11606]
#
# (6) ColumnarToRow
# Input [10]: [title#11597, industry#11598, release_year#11599L, imdb_rating#11600, studio#11601, budget#11602, revenue#11603, unit#11604, currency#11605, language#11606]
#
# (7) AdaptiveSparkPlan
# Output [10]: [title#11597, industry#11598, release_year#11599L, imdb_rating#11600, studio#11601, budget#11602, revenue#11603, unit#11604, currency#11605, language#11606]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial =
#   full    = movies

# %% [markdown]
# ### Partition in Round Robin Fashion

# %%
# 1) Make 6 compute partitions (round-robin shuffle)
rep_rr = df.repartition(6)
rep_rr.count()
# Out:
# 37

# %%
rep_rr.explain("formatted")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (8)
# +- == Initial Plan ==
#    ColumnarToRow (7)
#    +- PhotonResultStage (6)
#       +- PhotonShuffleExchangeSource (5)
#          +- PhotonShuffleMapStage (4)
#             +- PhotonShuffleExchangeSink (3)
#                +- PhotonSort (2)
#                   +- PhotonScan parquet workspace.default.movies (1)
#
#
# (1) PhotonScan parquet workspace.default.movies
# Output [10]: [title#11314, industry#11315, release_year#11316L, imdb_rating#11317, studio#11318, budget#11319, revenue#11320, unit#11321, currency#11322, language#11323]
# Location: PreparedDeltaFileIndex [s3://dbstorage-prod-ftgok/uc/79a99d11-bc4e-43f0-a401-b12e20be6025/fba37f23-14f9-4927-9ade-961e9f768757/__unitystorage/catalogs/175a67df-9974-43f3-a33a-f690ccef30f2/tables/bd69b1e4-307f-4ceb-8369-e74cf80f21d7]
# ReadSchema: struct<title:string,industry:string,release_year:bigint,imdb_rating:string,studio:string,budget:double,revenue:double,unit:string,currency:string,language:string>
#
# (2) PhotonSort
# Input [10]: [title#11314, industry#11315, release_year#11316L, imdb_rating#11317, studio#11318, budget#11319, revenue#11320, unit#11321, currency#11322, language#11323]
# Arguments: [title#11314 ASC NULLS FIRST, industry#11315 ASC NULLS FIRST, release_year#11316L ASC NULLS FIRST, imdb_rating#11317 ASC NULLS FIRST, studio#11318 ASC NULLS FIRST, budget#11319 ASC NULLS FIRST, revenue#11320 ASC NULLS FIRST, unit#11321 ASC NULLS FIRST, currency#11322 ASC NULLS FIRST, language#11323 ASC NULLS FIRST]
#
# (3) PhotonShuffleExchangeSink
# Input [10]: [title#11314, industry#11315, release_year#11316L, imdb_rating#11317, studio#11318, budget#11319, revenue#11320, unit#11321, currency#11322, language#11323]
# Arguments: RoundRobinPartitioning(6)
#
# (4) PhotonShuffleMapStage
# Input [10]: [title#11314, industry#11315, release_year#11316L, imdb_rating#11317, studio#11318, budget#11319, revenue#11320, unit#11321, currency#11322, language#11323]
# Arguments: REPARTITION_BY_NUM, [id=#7501]
#
# (5) PhotonShuffleExchangeSource
# Input [10]: [title#11314, industry#11315, release_year#11316L, imdb_rating#11317, studio#11318, budget#11319, revenue#11320, unit#11321, currency#11322, language#11323]
#
# (6) PhotonResultStage
# Input [10]: [title#11314, industry#11315, release_year#11316L, imdb_rating#11317, studio#11318, budget#11319, revenue#11320, unit#11321, currency#11322, language#11323]
#
# (7) ColumnarToRow
# Input [10]: [title#11314, industry#11315, release_year#11316L, imdb_rating#11317, studio#11318, budget#11319, revenue#11320, unit#11321, currency#11322, language#11323]
#
# (8) AdaptiveSparkPlan
# Output [10]: [title#11314, industry#11315, release_year#11316L, imdb_rating#11317, studio#11318, budget#11319, revenue#11320, unit#11321, currency#11322, language#11323]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial =
#   full    = movies

# %%
out_path = "/Volumes/workspace/default/partition_demo/repartition_6"
rep_rr.write.mode("overwrite").parquet(out_path)

# %% [markdown]
# Repartition by key helps if we have multiple per-studio operations such as below

# %%
from pyspark.sql import Window

# One-time shuffle:
base = df.repartition(6, "studio")

# Reuse partitioning on the same detailed rows:
agg    = base.groupBy("studio").agg(F.avg(F.col("revenue").cast("double")))
ranked = base.withColumn("rnk", F.row_number().over(Window.partitionBy("studio").orderBy(F.desc("revenue"))))

# %%
display(ranked)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>title</th><th>industry</th><th>release_year</th><th>imdb_rating</th><th>studio</th><th>budget</th><th>revenue</th><th>unit</th><th>currency</th><th>language</th><th>rnk</th></tr></thead><tbody><tr><td>Taare Zameen Par</td><td>Bollywood</td><td>2007</td><td>8.3</td><td>null</td><td>120.0</td><td>1350.0</td><td>Millions</td><td>INR</td><td>Hindi</td><td>1</td></tr><tr><td>Parasite</td><td>Hollywood</td><td>2019</td><td>8.5</td><td>null</td><td>15.5</td><td>263.1</td><td>Millions</td><td>USD</td><td>English</td><td>2</td></tr><tr><td>Bajirao Mastani </td><td>Bollywood</td><td>2015</td><td>7.2</td><td>null</td><td>1.4</td><td>3.5</td><td>Billions</td><td>INR</td><td>Hindi</td><td>3</td></tr><tr><td>Avengers: Endgame</td><td>Hollywood</td><td>2019</td><td>8.4</td><td>Marvel Studios</td><td>400.0</td><td>2798.0</td><td>Millions</td><td>USD</td><td>English</td><td>1</td></tr><tr><td>Avengers: Infinity War</td><td>Hollywood</td><td>2018</td><td>8.4</td><td>Marvel Studios</td><td>400.0</td><td>2048.0</td><td>Millions</td><td>USD</td><td>English</td><td>2</td></tr><tr><td>Doctor Strange in the Multiverse of Madness</td><td>Hollywood</td><td>2022</td><td>7</td><td>Marvel Studios</td><td>200.0</td><td>954.8</td><td>Millions</td><td>USD</td><td>English</td><td>3</td></tr><tr><td>Thor: Ragnarok </td><td>Hollywood</td><td>2017</td><td>7.9</td><td>Marvel Studios</td><td>180.0</td><td>854.0</td><td>Millions</td><td>USD</td><td>English</td><td>4</td></tr><tr><td>Captain America: The Winter Soldier</td><td>Hollywood</td><td>2014</td><td>7.8</td><td>Marvel Studios</td><td>177.0</td><td>714.4</td><td>Millions</td><td>USD</td><td>English</td><td>5</td></tr><tr><td>Thor: Love and Thunder </td><td>Hollywood</td><td>2022</td><td>6.8</td><td>Marvel Studios</td><td>250.0</td><td>670.0</td><td>Millions</td><td>USD</td><td>English</td><td>6</td></tr><tr><td>Thor: The Dark World </td><td>Hollywood</td><td>2013</td><td>6.8</td><td>Marvel Studios</td><td>165.0</td><td>644.8</td><td>Millions</td><td>USD</td><td>English</td><td>7</td></tr><tr><td>Captain America: The First Avenger</td><td>Hollywood</td><td>2011</td><td>6.9</td><td>Marvel Studios</td><td>216.7</td><td>370.6</td><td>Millions</td><td>USD</td><td>English</td><td>8</td></tr><tr><td>The Dark Knight</td><td>Hollywood</td><td>2008</td><td>9</td><td>Syncopy</td><td>185.0</td><td>1006.0</td><td>Millions</td><td>USD</td><td>English</td><td>1</td></tr><tr><td