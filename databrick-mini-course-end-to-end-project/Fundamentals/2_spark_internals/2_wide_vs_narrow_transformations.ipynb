# %% [markdown]
# ### Wide vs Narrow Transformations

# %%
df = spark.table("workspace.default.movies")
df.show(5)
# Out:
# +--------------------+---------+------------+-----------+--------------------+-------+--------+---------+--------+--------+
# |               title| industry|release_year|imdb_rating|              studio| budget| revenue|     unit|currency|language|
# +--------------------+---------+------------+-----------+--------------------+-------+--------+---------+--------+--------+
# |     Pather Panchali|Bollywood|        1955|        8.3|Government of Wes...|70000.0|100000.0|Thousands|     INR| Bengali|
# |Doctor Strange in...|Hollywood|        2022|          7|      Marvel Studios|  200.0|   954.8| Millions|     USD| English|
# |Thor: The Dark Wo...|Hollywood|        2013|        6.8|      Marvel Studios|  165.0|   644.8| Millions|     USD| English|
# |     Thor: Ragnarok |Hollywood|        2017|        7.9|      Marvel Studios|  180.0|   854.0| Millions|     USD| English|
# |Thor: Love and Th...|Hollywood|        2022|        6.8|      Marvel Studios|  250.0|   670.0| Millions|     USD| English|
# +--------------------+---------+------------+-----------+--------------------+-------+--------+---------+--------+--------+
# only showing top 5 rows

# %% [markdown]
# ### Narrow Transformation

# %%
from pyspark.sql import functions as F

df = spark.table("workspace.default.movies")
df_narrow = df.select("title","studio","imdb_rating").filter(F.col("release_year") >= 2010)


df_narrow.explain("extended")  # no Exchange
# Out:
# == Parsed Logical Plan ==
# 'Filter '`>=`('release_year, 2010)
# +- 'Project ['title, 'studio, 'imdb_rating]
#    +- 'UnresolvedRelation [workspace, default, movies], [], false
#
# == Analyzed Logical Plan ==
# title: string, studio: string, imdb_rating: string
# Project [title#11630, studio#11634, imdb_rating#11633]
# +- Filter (release_year#11632L >= cast(2010 as bigint))
#    +- Project [title#11630, studio#11634, imdb_rating#11633, release_year#11632L]
#       +- SubqueryAlias workspace.default.movies
#          +- Relation workspace.default.movies[title#11630,industry#11631,release_year#11632L,imdb_rating#11633,studio#11634,budget#11635,revenue#11636,unit#11637,currency#11638,language#11639] parquet
#
# == Optimized Logical Plan ==
# Project [title#11630, studio#11634, imdb_rating#11633]
# +- Filter (isnotnull(release_year#11632L) AND (release_year#11632L >= 2010))
#    +- Relation workspace.default.movies[title#11630,industry#11631,release_year#11632L,imdb_rating#11633,studio#11634,budget#11635,revenue#11636,unit#11637,currency#11638,language#11639] parquet
#
# == Physical Plan ==
# *(1) ColumnarToRow
# +- PhotonResultStage
#    +- PhotonProject [title#11630, studio#11634, imdb_rating#11633]
#       +- PhotonScan parquet workspace.default.movies[title#11630,release_year#11632L,imdb_rating#11633,studio#11634] DataFilters: [isnotnull(release_year#11632L), (release_year#11632L >= 2010)], DictionaryFilters: [(release_year#11632L >= 2010)], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://dbstorage-prod-ftgok/uc/79a99d11-bc4e-43f0-a401-b12e20be6025..., OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<title:string,release_year:bigint,imdb_rating:string,studio:string>, RequiredDataFilters: [isnotnull(release_year#11632L), (release_year#11632L >= 2010)]
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial =
#   full    = movies

# %%
df_narrow.explain("formatted")
# Out:
# == Physical Plan ==
# * ColumnarToRow (4)
# +- PhotonResultStage (3)
#    +- PhotonProject (2)
#       +- PhotonScan parquet workspace.default.movies (1)
#
#
# (1) PhotonScan parquet workspace.default.movies
# Output [4]: [title#11701, release_year#11703L, imdb_rating#11704, studio#11705]
# DictionaryFilters: [(release_year#11703L >= 2010)]
# Location: PreparedDeltaFileIndex [s3://dbstorage-prod-ftgok/uc/79a99d11-bc4e-43f0-a401-b12e20be6025/fba37f23-14f9-4927-9ade-961e9f768757/__unitystorage/catalogs/175a67df-9974-43f3-a33a-f690ccef30f2/tables/bd69b1e4-307f-4ceb-8369-e74cf80f21d7]
# ReadSchema: struct<title:string,release_year:bigint,imdb_rating:string,studio:string>
# RequiredDataFilters: [isnotnull(release_year#11703L), (release_year#11703L >= 2010)]
#
# (2) PhotonProject
# Input [4]: [title#11701, release_year#11703L, imdb_rating#11704, studio#11705]
# Arguments: [title#11701, studio#11705, imdb_rating#11704]
#
# (3) PhotonResultStage
# Input [3]: [title#11701, studio#11705, imdb_rating#11704]
#
# (4) ColumnarToRow [codegen id : 1]
# Input [3]: [title#11701, studio#11705, imdb_rating#11704]
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial =
#   full    = movies

# %%
display(df_narrow)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>title</th><th>studio</th><th>imdb_rating</th></tr></thead><tbody><tr><td>Doctor Strange in the Multiverse of Madness</td><td>Marvel Studios</td><td>7</td></tr><tr><td>Thor: The Dark World </td><td>Marvel Studios</td><td>6.8</td></tr><tr><td>Thor: Ragnarok </td><td>Marvel Studios</td><td>7.9</td></tr><tr><td>Thor: Love and Thunder </td><td>Marvel Studios</td><td>6.8</td></tr><tr><td>Interstellar</td><td>Warner Bros. Pictures</td><td>8.6</td></tr><tr><td>Parasite</td><td>null</td><td>8.5</td></tr><tr><td>Avengers: Endgame</td><td>Marvel Studios</td><td>8.4</td></tr><tr><td>Avengers: Infinity War</td><td>Marvel Studios</td><td>8.4</td></tr><tr><td>Captain America: The First Avenger</td><td>Marvel Studios</td><td>6.9</td></tr><tr><td>Captain America: The Winter Soldier</td><td>Marvel Studios</td><td>7.8</td></tr><tr><td>Bajirao Mastani </td><td>null</td><td>7.2</td></tr><tr><td>PK</td><td>Vinod Chopra Films</td><td>8.1</td></tr><tr><td>Sanju</td><td>Vinod Chopra Films</td><td>NULL</td></tr><tr><td>The Kashmir Files</td><td>Zee Studios</td><td>8.3</td></tr><tr><td>Bajrangi Bhaijaan</td><td>Salman Khan Films</td><td>8.1</td></tr><tr><td>Race 3</td><td>Salman Khan Films</td><td>1.9</td></tr><tr><td>Shershaah</td><td>Dharma Productions</td><td>8.4</td></tr><tr><td>K.G.F: Chapter 2</td><td>Hombale Films</td><td>8.4</td></tr><tr><td>Pushpa: The Rise - Part 1</td><td>Mythri Movie Makers</td><td>7.6</td></tr><tr><td>RRR</td><td>DVV Entertainment</td><td>8</td></tr><tr><td>Baahubali: The Beginning</td><td>Arka Media Works</td><td>8</td></tr></tbody></table></div>

# %% [markdown]
# ### Wide Transformation

# %%
spark.conf.set("spark.sql.shuffle.partitions", 4)

wide1 = (
    df.where(F.col("release_year") >= 2010)
      .repartition(4)
      .groupBy("studio")
      .agg(F.round(F.avg(F.col("revenue").cast("double")), 2).alias("avg_revenue"))
)
wide1.explain("formatted")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (14)
# +- == Initial Plan ==
#    ColumnarToRow (13)
#    +- PhotonResultStage (12)
#       +- PhotonGroupingAgg (11)
#          +- PhotonShuffleExchangeSource (10)
#             +- PhotonShuffleMapStage (9)
#                +- PhotonShuffleExchangeSink (8)
#                   +- PhotonGroupingAgg (7)
#                      +- PhotonShuffleExchangeSource (6)
#                         +- PhotonShuffleMapStage (5)
#                            +- PhotonShuffleExchangeSink (4)
#                               +- PhotonSort (3)
#                                  +- PhotonProject (2)
#                                     +- PhotonScan parquet workspace.default.movies (1)
#
#
# (1) PhotonScan parquet workspace.default.movies
# Output [3]: [release_year#11905L, studio#11907, revenue#11909]
# DictionaryFilters: [(release_year#11905L >= 2010)]
# Location: PreparedDeltaFileIndex [s3://dbstorage-prod-ftgok/uc/79a99d11-bc4e-43f0-a401-b12e20be6025/fba37f23-14f9-4927-9ade-961e9f768757/__unitystorage/catalogs/175a67df-9974-43f3-a33a-f690ccef30f2/tables/bd69b1e4-307f-4ceb-8369-e74cf80f21d7]
# ReadSchema: struct<release_year:bigint,studio:string,revenue:double>
# RequiredDataFilters: [isnotnull(release_year#11905L), (release_year#11905L >= 2010)]
#
# (2) PhotonProject
# Input [3]: [release_year#11905L, studio#11907, revenue#11909]
# Arguments: [studio#11907, revenue#11909]
#
# (3) PhotonSort
# Input [2]: [studio#11907, revenue#11909]
# Arguments: [studio#11907 ASC NULLS FIRST, revenue#11909 ASC NULLS FIRST]
#
# (4) PhotonShuffleExchangeSink
# Input [2]: [studio#11907, revenue#11909]
# Arguments: RoundRobinPartitioning(4)
#
# (5) PhotonShuffleMapStage
# Input [2]: [studio#11907, revenue#11909]
# Arguments: REPARTITION_BY_NUM, [id=#7858]
#
# (6) PhotonShuffleExchangeSource
# Input [2]: [studio#11907, revenue#11909]
#
# (7) PhotonGroupingAgg
# Input [2]: [studio#11907, revenue#11909]
# Arguments: [studio#11907], [partial_avg(revenue#11909) AS (sum#11923, count#11924L)], [sum#11921, count#11922L], [studio#11907, sum#11923, count#11924L], false
#
# (8) PhotonShuffleExchangeSink
# Input [3]: [studio#11907, sum#11923, count#11924L]
# Arguments: hashpartitioning(studio#11907, 4)
#
# (9) PhotonShuffleMapStage
# Input [3]: [studio#11907, sum#11923, count#11924L]
# Arguments: ENSURE_REQUIREMENTS, [id=#7864]
#
# (10) PhotonShuffleExchangeSource
# Input [3]: [studio#11907, sum#11923, count#11924L]
#
# (11) PhotonGroupingAgg
# Input [3]: [studio#11907, sum#11923, count#11924L]
# Arguments: [studio#11907], [finalmerge_avg(merge sum#11923, count#11924L) AS avg(revenue)#11914], [avg(revenue)#11914], [studio#11907, round(avg(revenue)#11914, 2) AS avg_revenue#11892], true
#
# (12) PhotonResultStage
# Input [2]: [studio#11907, avg_revenue#11892]
#
# (13) ColumnarToRow
# Input [2]: [studio#11907, avg_revenue#11892]
#
# (14) AdaptiveSparkPlan
# Output [2]: [studio#11907, avg_revenue#11892]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial =
#   full    = movies

# %%
display(wide1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>studio</th><th>avg_revenue</th></tr></thead><tbody><tr><td>Marvel Studios</td><td>1131.83</td></tr><tr><td>Warner Bros. Pictures</td><td>701.8</td></tr><tr><td>null</td><td>133.3</td></tr><tr><td>Vinod Chopra Films</td><td>4272.95</td></tr><tr><td>Zee Studios</td><td>3409.0</td></tr><tr><td>Salman Khan Films</td><td>5846.55</td></tr><tr><td>Dharma Productions</td><td>950.0</td></tr><tr><td>Hombale Films</td><td>12.5</td></tr><tr><td>Mythri Movie Makers</td><td>3.6</td></tr><tr><td>DVV Entertainment</td><td>12.0</td></tr><tr><td>Arka Media Works</td><td>6.5</td></tr></tbody></table></div>
